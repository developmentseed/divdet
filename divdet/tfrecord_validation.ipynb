# %% [markdown]
# # Simple TFRecord validation
#
# This notebook helps visualize simple stats about a TFRecords dataset to make sure it's formatted properly.

# %%
import os
import os.path as op
import tensorflow as tf
import tensorflow_data_validation as tfdv

# Define stats_options to only look at classes. Don't try to load raw image data here
stats_options = tfdv.StatsOptions(feature_whitelist=['image/object/class/text'])

#tfr_fpaths = [op.join(os.environ['DATA_DIR'], 'divot_detect', 'rocks_sample', 'data_rocks_rocks_v2.record')]
tfr_fpaths = [op.join(os.environ['DATA_DIR'], 'divot_detect', 'craters_sample', 'craters_moon_20200701.record')]

# %%
def print_example_info(example_dict):
    """Print out some high level information about a TFRecord example"""
    
    
    print(f'\nImage file name: {example_dict["image/filename"].bytes_list.value[0]}')
    print(f'Beginning of image byte str: {example_dict["image/encoded"].bytes_list.value[0][:20]}')
    print(f'Image dimensions (w x h): {example_dict["image/width"].int64_list.value} x '
          f'{example_dict["image/height"].int64_list.value}')

    print(f'Class labels: {example_dict["image/object/class/text"].bytes_list}')

# %%
# Loop over each TFRecord filenames
for tfr_fpath in tfr_fpaths:
    print(f'Analyzing {tfr_fpath}')

    # Compute and visualize stats about number of unique classes 
    stats = tfdv.generate_statistics_from_tfrecord(data_location=tfr_fpath, stats_options=stats_options)
    raw_dataset = tf.data.TFRecordDataset(tfr_fpath)

    # This will automatically plot
    viz = tfdv.visualize_statistics(stats)
    
    # Get and print examples from the TFRecord dataset
    tf_iterator = tf.python_io.tf_record_iterator(tfr_fpath)
    example_dicts = [dict(tf.train.Example.FromString(ex).features.feature) 
                     for ex in tf_iterator]
    for example_dict in example_dicts:
        print_example_info(example_dict)
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# Analyzing /Users/wronk/Data/divot_detect/craters_sample/craters_moon_20200701.record
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# WARNING:tensorflow:From /Users/wronk/.virtualenvs/mars/lib/python3.7/site-packages/tensorflow_data_validation/utils/stats_util.py:229: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /Users/wronk/.virtualenvs/mars/lib/python3.7/site-packages/tensorflow_data_validation/utils/stats_util.py:229: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="CqoBCg5saHNfc3RhdGlzdGljcxBIGpUBEAIidgp0CEgycBoJIc3MzMzMzBxAGgkhzczMzMzMHEAaCSHNzMzMzMwcQBoJIc3MzMzMzBxAGgkhzczMzMzMHEAaCSHNzMzMzMwcQBoJIc3MzMzMzBxAGgkhzczMzMzMHEAaCSHNzMzMzMwcQBoJIc3MzMzMzBxAIAFCGQoXaW1hZ2Uvb2JqZWN0L2NsYXNzL3RleHQ="></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
# Image file name: b'./moon_images/tile_4000_29000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_4000_27000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_4000_20000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_19000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_16000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_4000_39000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_38000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_32000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_35000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_26000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_22000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_4000_31000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_27000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_22000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_17000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_39000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_25000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_33000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_23000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_4000_38000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_4000_40000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_5000_16000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_37000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_15000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_16000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_5000_23000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_5000_26000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_27000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_19000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_33000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_35000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_5000_34000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_28000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_33000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_15000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_5000_39000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_39000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_4000_17000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_24000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_31000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_4000_18000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_38000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_5000_14000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_5000_20000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_19000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_9000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_38000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_30000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_15000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_39000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_5000_28000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_42000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_23000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_4000_15000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_17000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_37000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_27000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_5000_22000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_28000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_31000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_5000_32000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_36000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_16000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_34000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_3000_38000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_25000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_1000_18000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_33000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_24000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_0_26000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_35000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
#
# Image file name: b'./moon_images/tile_2000_24000.png'
# Beginning of image byte str: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'
# Image dimensions (w x h): [1000] x [1000]
# Class labels:
